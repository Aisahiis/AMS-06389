# %% [markdown]
# Nama : Aisah

# %% [markdown]
# NIM : A12.2020.06389

# %% [markdown]
# ## Eksperimen dan Pengumpulan Dataset

# %% [markdown]
# ## Pemanggilan Library 1

# %%
import pandas as pd
import time
import tweepy
import numpy as np

# %%
def twitter_config():
    """
    Fungsi utilitas untuk mengkonfigurasi konsumsi file API Twitter dengan␣
    ,!kunci yang disediakan.
    """
    
    # Autentikasi dan akses menggunakan keys
    auth = tweepy.OAuthHandler("jV2Vgyh72kWO7ruC9BVTJJ2fr", 
    "4n2V9A79zJ36FcM23qZ7mUbXYKcsVEH3AuQGn9h6Kf9BDbtZuw")
    auth.set_access_token("1574670640560238592-gepVeBNe0dZrmZ8i9XIAkiIVRNWLRt", 
    "L16cENiLN6tNYoCPWQdroEkOGrxZM7WwBMxpVpy1Us0MQ")
    
    # Kembalikan akses ke API
    api = tweepy.API(auth)
    try:
        api.verify_credentials()
        print("Authentication OK")
    except:
        print("Error during authentication")
    return api

# %%
# Membuat extractor object
extractor = twitter_config()
# Out:
# Authentication OK

# %% [markdown]
# ## Ambil Tweet dari Username
# Username yang saya gunakan yakni @isyanasarasvati

# %%
tweets = extractor.user_timeline(screen_name="isyanasarasvati", count=1000)
print("Tweets terambil: {}.\n".format(len(tweets)))

print("100 tweet teratas:\n")
for tweet in tweets[:100]:
    print(tweet.text)
    print()
# Out:
# Tweets terambil: 190.
#
# 100 tweet teratas:
#
# Happy anniversary IDNFT!! Sampai jumpa sebentar lagi jam (hampir) 5 sore yaa kita cerita-cerita lagi tentang my Mys… https://t.co/p9WZXtN3nu
#
# Besok bakal ikut memeriahkan panggung DeadSquad di LAKE STAGE @SynchronizeFest jam 21.40! Merapaat yaa bagi yang ak… https://t.co/CPmHxA1RNI
#
# Ini artinya good night 🙃🙃
#
# GN!! 🌝
#
# Here it is! My first my Mystery NFT AMA 🖤
#
# Aku bakal sharing dan cerita tentang project ini di Discord ku jam 8 mal… https://t.co/Gr3Oh0p1Ui
#
# Hi guys, I’m so excited to announce my first NFT project that i’ve been working on, my Mystery NFT Collection ✨
#
# Fi… https://t.co/4fwnuf1Wxt
#
# Biar seru, aku sambil bagi-bagi hadiah kali ya malem ini?? 🐣🌈✨
#
# Udah lama aku ga main di discord, besok main yuk guys jam 9:30 malem yaa seperti biasa!
#
# Discord Link:… https://t.co/OdVi30jVsb
#
# Morning, semangat ya 👀 https://t.co/QENefLZxrM
#
# Eh eh miring https://t.co/jCE5CMB4q5
#
# Maaacii 🥺🌈 https://t.co/MNoOCK01cF
#
# RT @Jvanz507: Isyana sihh Gokillll Di PestaPora @isyanasarasvati https://t.co/s2QaYV64RB
#
# PESTAPORA PECYAAH! Senang sekali bisa terus memperkenalkan karya-karya terbaru aku dari panggung ke panggung. Pelan… https://t.co/X048z4sElD
#
# Weekend ini kita ketemu dimana guyyss? 🤭
#
# I feel like I’m in love again. Congrats tedd! 🤍 https://t.co/JPPJa1mjar
#
# Jakarta, how I’ve missed you! Akhirnya sampe jugaa, gasabar pijeeet!
#
# RT @ditlicate: #LEXICONCERT @isyanasarasvati you’re the best. I LOVE YOU! 🫶🏻 https://t.co/2Q5wH6ETSO
#
# RT @ClassicRockMag: Vote for @isyanasarasvati's My Mystery as your Track Of The Week: https://t.co/WNhy8JriJj https://t.co/IqI2hLi8eQ
#
# WOWW my new song recently got featured in @ClassicRockMag thank you so much, it’s a true honor!❤️‍🔥
#
# https://t.co/kbOKkNHxig
#
# RT @anditasss: Lexiconcert jujur bikin melongo sih karna saking mengagumkannya🔥
#
# @isyanasarasvati https://t.co/qqMMn1j5DP
#
# RT @bayuwicks: @isyanasarasvati Kalau cari sekadar menyanyi sih banyak, nah yang ini lengkap dan tepat! Nonton lagi ah di Bandung
#
# #LEXICON…
#
# RT @mahathjr: setelah tertunda dua tahun, akhirnya #LEXICONCERT  teh @isyanasarasvati ! 🥹🤘🏻 https://t.co/IcicqSJfmD
#
# RT @kolonigigs_: Berapa kali kah Isyana Sarasvati (@isyanasarasvati ) melakukan headbang?
#
# #LEXICONCERT
#
# 📸: ladyasafa https://t.co/UxMh7Q…
#
# RT @gilang_jatnika: Momen yang paling ditunggu permainan handal dari @isyanasarasvati dan The tutti #LEXICONCERT https://t.co/GTcNkX0y99
#
# RT @gilang_jatnika: Opening yang keren, perkenalan the tuttis yg unik dan dilanjut lexicon sebagai penanda #LEXICONCERT dimulai @isyanasara…
#
# RT @nobinobiitaa: @isyanasarasvati GILAK, PECAH BANGET! semalem❤️‍🔥❤️‍🔥❤️‍🔥 Terharu banget akhirnya bisa terlaksana LEXICONCERTnya https://…
#
# RT @RaiNathania: THE QUEEN @isyanasarasvati
# yang juga ratu komedi.
#
# Membuka live concert saat pandemi ini dengan #LEXICONCERT yang bener-b…
#
# RT @bugubugupang: #LEXICONCERT Jakarta was beyond my expectation. The hero of the night was @isyanasarasvati setlist. Bukan LED Strip, Visu…
#
# RT @geraldhiras: Congrats LEXICONCERT Jakarta SANGAR! @isyanasarasvati
#
# Terharu juga setelah hampir tiga tahun rilis, terlibat sebagai pro…
#
# RT @322irl: "Madness" kata yang paling cocok untuk menggambarkan #LEXICONCERT kemarin.
#
# Aksi panggung @isyanasarasvati bener2 lepas dan ea…

# %% [markdown]
# ## Masukan ke dalam dataframes Pandas

# %%
# Membuat kerangka data menggunakan sintaks berikut
dataset = pd.DataFrame(data = [tweet.text for tweet in tweets], columns = ['Tweets'])

# Tampilan kerangka data
display(dataset.head(100))
# Out:
#                                                Tweets
# 0   Happy anniversary IDNFT!! Sampai jumpa sebenta...
# 1   Besok bakal ikut memeriahkan panggung DeadSqua...
# 2                           Ini artinya good night 🙃🙃
# 3                                              GN!! 🌝
# 4   Here it is! My first my Mystery NFT AMA 🖤\n\nA...
# ..                                                ...
# 95  RT @nobinobiitaa: @isyanasarasvati GILAK, PECA...
# 96  RT @RaiNathania: THE QUEEN @isyanasarasvati \n...
# 97  RT @bugubugupang: #LEXICONCERT Jakarta was bey...
# 98  RT @geraldhiras: Congrats LEXICONCERT Jakarta ...
# 99  RT @322irl: "Madness" kata yang paling cocok u...
#
# [100 rows x 1 columns]

# %%
dataset.to_csv('dataset_isyanasarasvati.csv')

# %% [markdown]
# ## Cleaning Word

# %% [markdown]
# ## Import Library untuk Cleaning Word

# %%
import pandas as pd
import re
import string
import time
from copy import deepcopy

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('dataset_isyanasarasvati.csv')

df.head()
# Out:
#    Unnamed: 0                                             Tweets
# 0           0  Happy anniversary IDNFT!! Sampai jumpa sebenta...
# 1           1  Besok bakal ikut memeriahkan panggung DeadSqua...
# 2           2                          Ini artinya good night 🙃🙃
# 3           3                                             GN!! 🌝
# 4           4  Here it is! My first my Mystery NFT AMA 🖤\n\nA...

# %%
df
# Out:
#      Unnamed: 0                                             Tweets
# 0             0  Happy anniversary IDNFT!! Sampai jumpa sebenta...
# 1             1  Besok bakal ikut memeriahkan panggung DeadSqua...
# 2             2                          Ini artinya good night 🙃🙃
# 3             3                                             GN!! 🌝
# 4             4  Here it is! My first my Mystery NFT AMA 🖤\n\nA...
# ..          ...                                                ...
# 185         185  RT @rintachos: Biarpun #DiRumahAja tapi tetap ...
# 186         186  RT @tinalfiana: Tau rasanya pengen jingkrak-ji...
# 187         187  RT @pramesshput: Really made my day❤️❤️❤️❤️❤️ ...
# 188         188  RT @brameasy: Thank you @isyanasarasvati virtu...
# 189         189  RT @fathimafildza: Thank you @isyanasarasvati ...
#
# [190 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  190 non-null    int64
#  1   Tweets      190 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 3.1+ KB

# %% [markdown]
# ## Preprocessing Dataset
# Pertama lakukan instalasi modul ekphrasis

# %%
# !pip install ekphrasis
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ekphrasis in c:\users\aisyah\appdata\roaming\python\python39\site-packages (0.5.4)
# Requirement already satisfied: ftfy in c:\users\aisyah\appdata\roaming\python\python39\site-packages (from ekphrasis) (6.1.1)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from ekphrasis) (3.5.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ekphrasis) (0.4.4)
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (from ekphrasis) (3.7)
# Requirement already satisfied: ujson in c:\programdata\anaconda3\lib\site-packages (from ekphrasis) (5.1.0)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from ekphrasis) (4.64.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from ekphrasis) (1.21.5)
# Requirement already satisfied: termcolor in c:\users\aisyah\appdata\roaming\python\python39\site-packages (from ekphrasis) (2.0.1)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\programdata\anaconda3\lib\site-packages (from ftfy->ekphrasis) (0.2.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->ekphrasis) (1.16.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk->ekphrasis) (2022.3.15)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk->ekphrasis) (1.1.0)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk->ekphrasis) (8.0.4)

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# C:\Users\Aisyah\AppData\Roaming\Python\Python39\site-packages\ekphrasis\classes\tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...
# C:\Users\Aisyah\AppData\Roaming\Python\Python39\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in

# %%
# panggil ekphrasis

def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

# %%
# fungsi dari AMS 01-03. silakan cek bagaimana saya merubah menjadi fungsi

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space(text):
    return " ".join(text.split())

def remove_emoji(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def lower(text):
    return text.lower()

def remove_whitespace_LT(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text)

# %%
# hapus untuk <>
def remove_number_eks(text):
    return text.replace('<number>'," ")

def remove_angka(text):
    return re.sub(r"\d+", "", text) 

def remove_URL_eks(text):
    return text.replace('URL'," ").replace('url'," ")

def space_punctuation(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text)

# %% [markdown]
# ## Mulai Proses Pembersihan

# %%
i = 0
final_string = []
s = ""
for text in df['Tweets'].values:
    filteredSentence = []
    EachReviewText = ""
    proc = remove_rt(text)
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_emoji(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_excessive_dot(proc)
    proc = remove_whitespace_LT(proc)
    proc = remove_whitespace_multiple(proc)
    proc = remove_single_char(proc)
    proc = space_punctuation(proc)
    proc = remove_punctuation(proc)
    proc = remove_space(proc)
    proc = bersih_data(proc)
    proc = remove_number_eks(proc)
    proc = remove_angka(proc) 
    proc = remove_URL_eks(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %%
df["step01"] = final_string

# %%
df.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0           0  Happy anniversary IDNFT!! Sampai jumpa sebenta...
# 1           1  Besok bakal ikut memeriahkan panggung DeadSqua...
# 2           2                          Ini artinya good night 🙃🙃
# 3           3                                             GN!! 🌝
# 4           4  Here it is! My first my Mystery NFT AMA 🖤\n\nA...
# 5           5  Hi guys, I’m so excited to announce my first N...
# 6           6  Biar seru, aku sambil bagi-bagi hadiah kali ya...
# 7           7  Udah lama aku ga main di discord, besok main y...
# 8           8     Morning, semangat ya 👀 https://t.co/QENefLZxrM
# 9           9               Eh eh miring https://t.co/jCE5CMB4q5
#
#                                               step01
# 0  happy anniversary idnft sampai jumpa sebentar ...
# 1  besok bakal ikut memeriahkan panggung deadsqua...
# 2                             ini artinya good night
# 3                                                 gn
# 4  here it is my first my mystery nft ama aku bak...
# 5  hi guys so to announce my first nft project th...
# 6  biar seru aku sambil bagi bagi hadiah kali ya ...
# 7  udah lama aku ga main di discord besok main yu...
# 8                      morning semangat ya coqeneflz
# 9                             eh eh miring cojcecmbq

# %% [markdown]
# ## Hapus Data Kosong

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  190 non-null    int64
#  1   Tweets      190 non-null    object
#  2   step01      190 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.6+ KB

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

# %%
df_hapus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 3 to 183
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  6 non-null      int64
#  1   Tweets      6 non-null      object
#  2   step01      6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 192.0+ bytes

# %%
df_hapus.head(10)
# Out:
#      Unnamed: 0                          Tweets       step01
# 3             3                          GN!! 🌝           gn
# 36           36     🖤❤️ https://t.co/Z8mnbWruFf  cozmnbwruff
# 55           55  🙏❤️‍🔥😇 https://t.co/Eq7J7q374e      coeqjqe
# 144         144   😜😜😜🙏🏻 https://t.co/U5T1uk9bfq    coutukbfq
# 179         179  ❤️❤️❤️ https://t.co/V5G7w6enEH    covgweneh
# 183         183     🤣🤣🤣 https://t.co/U4xo73i1z8          cou

# %%
df_new = df[~df.isin(df_hapus)].dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184 entries, 0 to 189
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  184 non-null    float64
#  1   Tweets      184 non-null    object
#  2   step01      184 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 5.8+ KB

# %%
df_new
# Out:
#      Unnamed: 0                                             Tweets  \
# 0           0.0  Happy anniversary IDNFT!! Sampai jumpa sebenta...
# 1           1.0  Besok bakal ikut memeriahkan panggung DeadSqua...
# 2           2.0                          Ini artinya good night 🙃🙃
# 4           4.0  Here it is! My first my Mystery NFT AMA 🖤\n\nA...
# 5           5.0  Hi guys, I’m so excited to announce my first N...
# ..          ...                                                ...
# 185       185.0  RT @rintachos: Biarpun #DiRumahAja tapi tetap ...
# 186       186.0  RT @tinalfiana: Tau rasanya pengen jingkrak-ji...
# 187       187.0  RT @pramesshput: Really made my day❤️❤️❤️❤️❤️ ...
# 188       188.0  RT @brameasy: Thank you @isyanasarasvati virtu...
# 189       189.0  RT @fathimafildza: Thank you @isyanasarasvati ...
#
#                                                 step01
# 0    happy anniversary idnft sampai jumpa sebentar ...
# 1    besok bakal ikut memeriahkan panggung deadsqua...
# 2                               ini artinya good night
# 4    here it is my first my mystery nft ama aku bak...
# 5    hi guys so to announce my first nft project th...
# ..                                                 ...
# 185  rintachos biarpun tapi tetap mau menangos nont...
# 186  tinalfiana tau rasanya pengen jingkrak jingkra...
# 187  pramesshput really made my day tidak sia membu...
# 188  brameasy thank you isyanasarasvati virtual con...
# 189  fathimafildza thank you isyanasarasvati the le...
#
# [184 rows x 3 columns]

# %% [markdown]
# ## Normalisasi kata slang menjadi baku

# %%
# token
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Aisyah\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df["step01"].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#     Unnamed: 0                                             Tweets  \
# 0          0.0  Happy anniversary IDNFT!! Sampai jumpa sebenta...
# 1          1.0  Besok bakal ikut memeriahkan panggung DeadSqua...
# 2          2.0                          Ini artinya good night 🙃🙃
# 4          4.0  Here it is! My first my Mystery NFT AMA 🖤\n\nA...
# 5          5.0  Hi guys, I’m so excited to announce my first N...
# 6          6.0  Biar seru, aku sambil bagi-bagi hadiah kali ya...
# 7          7.0  Udah lama aku ga main di discord, besok main y...
# 8          8.0     Morning, semangat ya 👀 https://t.co/QENefLZxrM
# 9          9.0               Eh eh miring https://t.co/jCE5CMB4q5
# 10        10.0                 Maaacii 🥺🌈 https://t.co/MNoOCK01cF
#
#                                                step01  \
# 0   happy anniversary idnft sampai jumpa sebentar ...
# 1   besok bakal ikut memeriahkan panggung deadsqua...
# 2                              ini artinya good night
# 4   here it is my first my mystery nft ama aku bak...
# 5   hi guys so to announce my first nft project th...
# 6   biar seru aku sambil bagi bagi hadiah kali ya ...
# 7   udah lama aku ga main di discord besok main yu...
# 8                       morning semangat ya coqeneflz
# 9                              eh eh miring cojcecmbq
# 10                                 maaacii comnoockcf
#
#                                                tokens
# 0   [happy, anniversary, idnft, sampai, jumpa, seb...
# 1   [besok, bakal, ikut, memeriahkan, panggung, de...
# 2                         [ini, artinya, good, night]
# 4   [here, it, is, my, first, my, mystery, nft, am...
# 5   [hi, guys, so, to, announce, my, first, nft, p...
# 6   [biar, seru, aku, sambil, bagi, bagi, hadiah, ...
# 7   [udah, lama, aku, ga, main, di, discord, besok...
# 8                  [morning, semangat, ya, coqeneflz]
# 9                         [eh, eh, miring, cojcecmbq]
# 10                              [maaacii, comnoockcf]

# %%
normalized_word = pd.read_csv('kamus_clean.csv')

# %%
normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

# %%
df_new['final_tokens'] = df_new['tokens'].apply(normalized_term)

# %%
i=0
final_string_tokens = []
for text in df_new['final_tokens'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

# %%
df_new.head(10)
# Out:
#     Unnamed: 0                                             Tweets  \
# 0          0.0  Happy anniversary IDNFT!! Sampai jumpa sebenta...
# 1          1.0  Besok bakal ikut memeriahkan panggung DeadSqua...
# 2          2.0                          Ini artinya good night 🙃🙃
# 4          4.0  Here it is! My first my Mystery NFT AMA 🖤\n\nA...
# 5          5.0  Hi guys, I’m so excited to announce my first N...
# 6          6.0  Biar seru, aku sambil bagi-bagi hadiah kali ya...
# 7          7.0  Udah lama aku ga main di discord, besok main y...
# 8          8.0     Morning, semangat ya 👀 https://t.co/QENefLZxrM
# 9          9.0               Eh eh miring https://t.co/jCE5CMB4q5
# 10        10.0                 Maaacii 🥺🌈 https://t.co/MNoOCK01cF
#
#                                                step01  \
# 0   happy anniversary idnft sampai jumpa sebentar ...
# 1   besok bakal ikut memeriahkan panggung deadsqua...
# 2                              ini artinya good night
# 4   here it is my first my mystery nft ama aku bak...
# 5   hi guys so to announce my first nft project th...
# 6   biar seru aku sambil bagi bagi hadiah kali ya ...
# 7   udah lama aku ga main di discord besok main yu...
# 8                       morning semangat ya coqeneflz
# 9                              eh eh miring cojcecmbq
# 10                                 maaacii comnoockcf
#
#                                                tokens  \
# 0   [happy, anniversary, idnft, sampai, jumpa, seb...
# 1   [besok, bakal, ikut, memeriahkan, panggung, de...
# 2                         [ini, artinya, good, night]
# 4   [here, it, is, my, first, my, mystery, nft, am...
# 5   [hi, guys, so, to, announce, my, first, nft, p...
# 6   [biar, seru, aku, sambil, bagi, bagi, hadiah, ...
# 7   [udah, lama, aku, ga, main, di, discord, besok...
# 8                  [morning, semangat, ya, coqeneflz]
# 9                         [eh, eh, miring, cojcecmbq]
# 10                              [maaacii, comnoockcf]
#
#                                          final_tokens  \
# 0   [happy, anniversary, idnft, sampai, jumpa, seb...
# 1   [besok, bakal, ikut, memeriahkan, panggung, de...
# 2                         [ini, artinya, good, night]
# 4   [here, it, is, my, first, my, mystery, nft, am...
# 5   [hi, guys, so, to, announce, my, first, nft, p...
# 6   [biar, seru, aku, sambil, bagi, bagi, hadiah, ...
# 7   [udah, lama, aku, ga, main, di, discord, besok...
# 8                  [morning, semangat, ya, coqeneflz]
# 9                         [eh, eh, miring, cojcecmbq]
# 10                              [maaacii, comnoockcf]
#
#                                                step02
# 0   happy anniversary idnft sampai jumpa sebentar ...
# 1   besok bakal ikut memeriahkan panggung deadsqua...
# 2                              ini artinya good night
# 4   here it is my first my mystery nft ama aku bak...
# 5   hi guys so to announce my first nft project th...
# 6   biar seru aku sambil bagi bagi hadiah kali ya ...
# 7   udah lama aku ga main di discord besok main yu...
# 8                       morning semangat ya coqeneflz
# 9                              eh eh miring cojcecmbq
# 10                                 maaacii comnoockcf

# %% [markdown]
# ## Simpan clean dataset

# %%
df_new.to_csv('clean_dataset_isyanasarasvati')
